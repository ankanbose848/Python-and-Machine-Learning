# %% [markdown]
# # Practice Homework 1

# %% [markdown]
# ## Data analysis of IRIS Dataset

# %%
import seaborn as sns

# %%
## Practice homework

iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris.corr())

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris, hue='species')

# %%
sns.distplot(iris['sepal_length'])

# %%
sns.distplot(iris['sepal_width'])

# %%
sns.distplot(iris['petal_length'])

# %%
sns.distplot(iris['petal_width'])

# %%
print(iris.species.value_counts())

sns.countplot('species', data=iris)
# Out:
# virginica     50
# versicolor    50
# setosa        50
# Name: species, dtype: int64

# %%
sns.barplot(x='species', y='sepal_length', data=iris)

# %%
sns.barplot(x='species', y='sepal_width', data=iris)

# %%
sns.barplot(x='species', y='petal_length', data=iris)

# %%
sns.barplot(x='species', y='petal_width', data=iris)

# %%
sns.boxplot('species', 'sepal_length', data=iris)

# %%
sns.boxplot('species', 'sepal_width', data=iris)

# %%
sns.boxplot('species', 'petal_length', data=iris)

# %%
sns.boxplot('species', 'petal_width', data=iris)

# %%
sns.violinplot('species', 'sepal_length', data=iris, palette='rainbow')

# %%
sns.violinplot('species', 'sepal_width', data=iris, palette='rainbow')

# %%
sns.violinplot('species', 'petal_length', data=iris, palette='rainbow')

# %%
sns.violinplot('species', 'petal_width', data=iris, palette='rainbow')
